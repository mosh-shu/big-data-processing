# %%
import numpy as np
import csv

# %%
with open('73.csv') as f:
    reader = csv.reader(f)
    l = [row for row in reader]

# %%
lines = np.size(l, 0)
new_lines = np.random.randint(0, lines, (1, 10000))[0, :]

# %%
new_data = list()
for new_line in new_lines:
    new_data.append(l[new_line])

# %%
new_data
# Out:
# [['2014-03-30 08:56:58 +0900', '52.000', '0.151'],
#  ['2013-09-15 13:15:11 +0900', '41.000', '0.119'],
#  ['2012-11-23 06:16:18 +0900', '43.000', '0.125'],
#  ['2014-06-02 15:13:22 +0900', '30.000', '0.087'],
#  ['2013-09-28 22:41:47 +0900', '51.000', '0.148'],
#  ['2013-08-02 04:40:40 +0900', '35.000', '0.102'],
#  ['2012-01-31 23:16:26 +0900', '40.000', '0.116'],
#  ['2013-02-18 07:02:27 +0900', '41.000', '0.119'],
#  ['2012-12-14 17:49:53 +0900', '34.000', '0.099'],
#  ['2012-09-16 05:12:02 +0900', '35.000', '0.102'],
#  ['2014-04-13 18:15:47 +0900', '39.000', '0.113'],
#  ['2014-03-05 15:38:43 +0900', '38.000', '0.110'],
#  ['2012-07-11 21:27:26 +0900', '47.000', '0.136'],
#  ['2014-03-18 02:00:24 +0900', '35.000', '0.102'],
#  ['2012-10-23 17:23:58 +0900', '48.000', '0.139'],
#  ['2013-11-05 14:57:04 +0900', '38.000', '0.110'],
#  ['2014-02-18 20:03:09 +0900', '36.000', '0.104'],
#  ['2013-05-27 15:35:06 +0900', '45.000', '0.131'],
# ...
